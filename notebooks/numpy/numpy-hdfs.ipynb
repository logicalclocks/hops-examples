# %% [markdown]
# Numpy - read/write CSV files with HopsFS (HDFS)
# -------------------------------------------------------------------------------

# %%
from hops import hdfs
from hops import numpy
data = numpy.loadnp("Resources/C_test.npy")

data.shape

numpy.savenp("Resources/project-relative-path.npy", data)
numpy.savenp(hdfs.project_path() + "/Resources/full-path.npy", data)
