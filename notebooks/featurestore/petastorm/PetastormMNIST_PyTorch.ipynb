# %% [markdown]
# # Image Classification with MNIST Using a Petastorm Dataset and PyTorch
#
# In this notebook we will read a training dataset saved in the Petastorm format in the project's feature store and use that to train a Deep CNN defined in PyTorch to classify images of digits in the MNIST dataset.
#
# This notebook assumes that you have already created the training datasets in the feature store, which you can do by running this notebook:
#
# [Create Petastorm MNIST Dataset Notebook](PetastormMNIST_CreateDataset.ipynb)
#
# ![Petastorm 7](./../images/petastorm7.png "Petastorm 7")

# %%
from hops import hdfs, featurestore
import numpy as np
import pydoop
from petastorm import make_reader
from petastorm.tf_utils import tf_tensors, make_petastorm_dataset
import torch
import torch.nn as nn
from hops import experiment
import torch.optim as optim
from torchvision import transforms
import torch.nn.functional as F
from petastorm.pytorch import DataLoader
from hops import tensorboard
from hops import hdfs
import json
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>15</td><td>application_1550835076939_0017</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://hopsworks0.logicalclocks.com:8088/proxy/application_1550835076939_0017/">Link</a></td><td><a target="_blank" href="http://hopsworks0.logicalclocks.com:8042/node/containerlogs/container_e01_1550835076939_0017_01_000001/demo_featurestore_admin000__meb10000">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.

# %% [markdown]
# ## Constants

# %%
TRAIN_DATASET_NAME = "MNIST_train_petastorm"
TEST_DATASET_NAME = "MNIST_test_petastorm"
BATCH_SIZE = 50
NUM_EPOCHS = 5
LEARNING_RATE = 0.01
MOMENTUM = 0.001
SEED = 1
LOG_INTERVAL = 10
READER_EPOCHS = 1
PROJECT_PATH = hdfs.project_path()

# %% [markdown]
# ## Step 1: Define The Model

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# ## Step 2: Define PyTorch Dataset Transformer
#
# Petastorm datasets can be read directly with PyTorch by using `make_reader` and `make_petastorm_dataset` from the Petastorm library

# %%
def _transform_row(mnist_row):
    """
    Normalize images
    """
    transform = transforms.Compose([
        transforms.Lambda(lambda nd: nd.reshape(28, 28, 1)),
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    # In addition, the petastorm pytorch DataLoader does not distinguish the notion of
    # data or target transform, but that actually gives the user more flexibility
    # to make the desired partial transform, as shown here.
    result_row = {
        'image': transform(mnist_row['image']),
        'digit': mnist_row['digit']
    }

    return result_row

# %% [markdown]
# ## Step 3: Define Epoch Reader and Training Loop

# %%
def train_epoch(train_dataset_path, model, device, optimizer, epoch):
    """
    Function for training a single epoch of MNIST using PyTorch
    """
    with DataLoader(make_reader(train_dataset_path, num_epochs=READER_EPOCHS, hdfs_driver='libhdfs'), 
                    batch_size=BATCH_SIZE, transform=_transform_row) as train_loader:
        correct = 0
        count = 0
        train_loss = 0
        model.train()
        for batch_idx, row in enumerate(train_loader):
            data, target = row['image'].to(device), row['digit'].to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = F.nll_loss(output, target)
            train_loss += loss.item()
            pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            count += data.shape[0]
            loss.backward()
            optimizer.step()
            if batch_idx % LOG_INTERVAL == 0:
                print('Train Epoch: {} [{}]\tLoss: {:.6f}'.format(
                    epoch, batch_idx * len(data), loss.item()))
        train_accuracy = correct / count
        train_loss /= count
        return train_accuracy, train_loss, epoch

# %% [markdown]
# ## Step 4: Put it All Together in a Training Function

# %%
def train_fn():
    """
    The training loop
    """
    # Setup Torch
    use_cuda = torch.cuda.is_available()
    torch.manual_seed(SEED)
    device = torch.device('cuda' if use_cuda else 'cpu')
    # Create Model
    model = Net().to(device)
    # Define optimizer
    optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
    # get dataset path from the featurestore
    train_dataset_path = featurestore.get_training_dataset_path(TRAIN_DATASET_NAME)
    train_history = {}
    train_epochs = []
    train_accuracies = []
    train_losses = []
    for epoch in range(1, NUM_EPOCHS + 1):
        train_accuracy, train_loss, epoch = train_epoch(train_dataset_path, model, device, optimizer, epoch)
        train_epochs.append(epoch)
        train_accuracies.append(train_accuracy)
        train_losses.append(train_loss)
    torch.save(model.state_dict(), "mnist_torch_ps.pt") #PyTorch can't save to HDFS in the current version so save to local fs first
    hdfs.copy_to_hdfs("mnist_torch_ps.pt", hdfs.project_path() + "mnist/mnist_torch_ps.pt", overwrite=True) # copy from local fs to hdfs
    train_history["acc"] = train_accuracies
    train_history["epoch"] = train_epochs
    train_history["loss"] = train_losses
    # save training history to HDFS
    results_path = hdfs.project_path() + "mnist/mnist_train_results_2.txt"
    hdfs.dump(json.dumps(train_history), results_path)
    return train_history

# %% [markdown]
# ## Step 5: Training Experiments

# %%
train_history = train_fn()
# Out:
# Train Epoch: 1 [0]	Loss: 2.314652
# Train Epoch: 1 [500]	Loss: 2.347810
# Train Epoch: 1 [1000]	Loss: 2.322586
# Train Epoch: 1 [1500]	Loss: 2.292396
# Train Epoch: 1 [2000]	Loss: 2.293021
# Train Epoch: 1 [2500]	Loss: 2.279352
# Train Epoch: 1 [3000]	Loss: 2.323452
# Train Epoch: 1 [3500]	Loss: 2.277730
# Train Epoch: 1 [4000]	Loss: 2.245240
# Train Epoch: 1 [4500]	Loss: 2.224981
# Train Epoch: 1 [5000]	Loss: 2.203325
# Train Epoch: 1 [5500]	Loss: 2.202740
# Train Epoch: 1 [6000]	Loss: 2.194582
# Train Epoch: 1 [6500]	Loss: 2.204894
# Train Epoch: 1 [7000]	Loss: 2.185441
# Train Epoch: 1 [7500]	Loss: 2.105492
# Train Epoch: 1 [8000]	Loss: 2.085393
# Train Epoch: 1 [8500]	Loss: 2.058236
# Train Epoch: 1 [9000]	Loss: 1.886974
# Train Epoch: 1 [9500]	Loss: 1.932889
# Train Epoch: 1 [10000]	Loss: 1.965610
# Train Epoch: 1 [10500]	Loss: 1.861649
# Train Epoch: 1 [11000]	Loss: 1.852183
# Train Epoch: 1 [11500]	Loss: 1.785226
# Train Epoch: 1 [12000]	Loss: 1.769208
# Train Epoch: 1 [12500]	Loss: 1.805642
# Train Epoch: 1 [13000]	Loss: 1.608439
# Train Epoch: 1 [13500]	Loss: 1.552279
# Train Epoch: 1 [14000]	Loss: 1.948089
# Train Epoch: 1 [14500]	Loss: 1.627441
# Train Epoch: 1 [15000]	Loss: 1.343279
# Train Epoch: 1 [15500]	Loss: 1.333905
# Train Epoch: 1 [16000]	Loss: 1.867580
# Train Epoch: 1 [16500]	Loss: 1.079157
# Train Epoch: 1 [17000]	Loss: 1.271716
# Train Epoch: 1 [17500]	Loss: 1.448447
# Train Epoch: 1 [18000]	Loss: 1.327411
# Train Epoch: 1 [18500]	Loss: 1.075074
# Train Epoch: 1 [19000]	Loss: 1.403568
# Train Epoch: 1 [19500]	Loss: 1.186902
# Train Epoch: 1 [20000]	Loss: 1.367946
# Train Epoch: 1 [20500]	Loss: 1.143413
# Train Epoch: 1 [21000]	Loss: 1.270545
# Train Epoch: 1 [21500]	Loss: 1.022838
# Train Epoch: 1 [22000]	Loss: 0.692186
# Train Epoch: 1 [22500]	Loss: 1.192607
# Train Epoch: 1 [23000]	Loss: 0.927546
# Train Epoch: 1 [23500]	Loss: 0.882505
# Train Epoch: 1 [24000]	Loss: 0.932282
# Train Epoch: 1 [24500]	Loss: 1.091792
# Train Epoch: 1 [25000]	Loss: 1.033272
# Train Epoch: 1 [25500]	Loss: 0.552138
# Train Epoch: 1 [26000]	Loss: 0.670877
# Train Epoch: 1 [26500]	Loss: 1.139475
# Train Epoch: 1 [27000]	Loss: 0.794613
# Train Epoch: 1 [27500]	Loss: 0.947653
# Train Epoch: 1 [28000]	Loss: 0.666112
# Train Epoch: 1 [28500]	Loss: 0.985433
# Train Epoch: 1 [29000]	Loss: 1.017190
# Train Epoch: 1 [29500]	Loss: 0.740639
# Train Epoch: 1 [30000]	Loss: 1.038814
# Train Epoch: 1 [30500]	Loss: 1.019372
# Train Epoch: 1 [31000]	Loss: 0.878289
# Train Epoch: 1 [31500]	Loss: 0.624353
# Train Epoch: 1 [32000]	Loss: 0.623673
# Train Epoch: 1 [32500]	Loss: 1.112475
# Train Epoch: 1 [33000]	Loss: 0.843195
# Train Epoch: 1 [33500]	Loss: 0.638412
# Train Epoch: 1 [34000]	Loss: 0.986537
# Train Epoch: 1 [34500]	Loss: 0.796048
# Train Epoch: 1 [35000]	Loss: 0.554664
# Train Epoch: 1 [35500]	Loss: 0.748928
# Train Epoch: 1 [36000]	Loss: 0.682812
# Train Epoch: 1 [36500]	Loss: 0.702814
# Train Epoch: 1 [37000]	Loss: 0.788767
# Train Epoch: 1 [37500]	Loss: 0.738631
# Train Epoch: 1 [38000]	Loss: 0.623706
# Train Epoch: 1 [38500]	Loss: 0.980909
# Train Epoch: 1 [39000]	Loss: 0.562347
# Train Epoch: 1 [39500]	Loss: 0.643081
# Train Epoch: 1 [40000]	Loss: 0.606500
# Train Epoch: 1 [40500]	Loss: 0.741372
# Train Epoch: 1 [41000]	Loss: 0.767001
# Train Epoch: 1 [41500]	Loss: 0.851955
# Train Epoch: 1 [42000]	Loss: 0.745320
# Train Epoch: 1 [42500]	Loss: 1.126007
# Train Epoch: 1 [43000]	Loss: 0.791516
# Train Epoch: 1 [43500]	Loss: 0.712783
# Train Epoch: 1 [44000]	Loss: 0.712890
# Train Epoch: 1 [44500]	Loss: 0.393116
# Train Epoch: 1 [45000]	Loss: 1.166684
# Train Epoch: 1 [45500]	Loss: 0.731376
# Train Epoch: 1 [46000]	Loss: 0.670420
# Train Epoch: 1 [46500]	Loss: 0.359363
# Train Epoch: 1 [47000]	Loss: 0.735208
# Train Epoch: 1 [47500]	Loss: 0.571186
# Train Epoch: 1 [48000]	Loss: 0.550910
# Train Epoch: 1 [48500]	Loss: 0.405404
# Train Epoch: 1 [49000]	Loss: 0.781007
# Train Epoch: 1 [49500]	Loss: 1.207737
# Train Epoch: 1 [50000]	Loss: 0.572667
# Train Epoch: 1 [50500]	Loss: 0.621670
# Train Epoch: 1 [51000]	Loss: 0.362507
# Train Epoch: 1 [51500]	Loss: 0.655981
# Train Epoch: 1 [52000]	Loss: 0.644185
# Train Epoch: 1 [52500]	Loss: 0.434025
# Train Epoch: 1 [53000]	Loss: 0.710513
# Train Epoch: 1 [53500]	Loss: 0.485136
# Train Epoch: 1 [54000]	Loss: 0.745091
# Train Epoch: 1 [54500]	Loss: 0.645055
# Train Epoch: 1 [55000]	Loss: 0.605292
# Train Epoch: 1 [55500]	Loss: 0.368332
# Train Epoch: 1 [56000]	Loss: 0.305995
# Train Epoch: 1 [56500]	Loss: 0.448098
# Train Epoch: 1 [57000]	Loss: 0.533490
# Train Epoch: 1 [57500]	Loss: 0.545217
# Train Epoch: 1 [58000]	Loss: 0.400070
# Train Epoch: 1 [58500]	Loss: 0.210642
# Train Epoch: 1 [59000]	Loss: 0.234924
# Train Epoch: 1 [59500]	Loss: 0.210139
# Train Epoch: 2 [0]	Loss: 0.631590
# Train Epoch: 2 [500]	Loss: 0.923755
# Train Epoch: 2 [1000]	Loss: 0.683810
# Train Epoch: 2 [1500]	Loss: 0.536755
# Train Epoch: 2 [2000]	Loss: 0.583845
# Train Epoch: 2 [2500]	Loss: 0.382812
# Train Epoch: 2 [3000]	Loss: 0.625116
# Train Epoch: 2 [3500]	Loss: 0.737621
# Train Epoch: 2 [4000]	Loss: 0.487222
# Train Epoch: 2 [4500]	Loss: 0.460819
# Train Epoch: 2 [5000]	Loss: 0.482390
# Train Epoch: 2 [5500]	Loss: 0.422050
# Train Epoch: 2 [6000]	Loss: 0.458193
# Train Epoch: 2 [6500]	Loss: 0.415911
# Train Epoch: 2 [7000]	Loss: 0.759328
# Train Epoch: 2 [7500]	Loss: 0.648996
# Train Epoch: 2 [8000]	Loss: 0.434421
# Train Epoch: 2 [8500]	Loss: 0.458697
# Train Epoch: 2 [9000]	Loss: 0.286253
# Train Epoch: 2 [9500]	Loss: 0.422498
# Train Epoch: 2 [10000]	Loss: 0.481136
# Train Epoch: 2 [10500]	Loss: 0.409842
# Train Epoch: 2 [11000]	Loss: 0.366786
# Train Epoch: 2 [11500]	Loss: 0.463327
# Train Epoch: 2 [12000]	Loss: 0.447665
# Train Epoch: 2 [12500]	Loss: 0.656437
# Train Epoch: 2 [13000]	Loss: 0.875630
# Train Epoch: 2 [13500]	Loss: 0.393882
# Train Epoch: 2 [14000]	Loss: 0.443020
# Train Epoch: 2 [14500]	Loss: 0.822608
# Train Epoch: 2 [15000]	Loss: 0.281886
# Train Epoch: 2 [15500]	Loss: 0.430993
# Train Epoch: 2 [16000]	Loss: 0.818680
# Train Epoch: 2 [16500]	Loss: 0.240705
# Train Epoch: 2 [17000]	Loss: 0.402048
# Train Epoch: 2 [17500]	Loss: 0.430276
# Train Epoch: 2 [18000]	Loss: 0.594681
# Train Epoch: 2 [18500]	Loss: 0.429612
# Train Epoch: 2 [19000]	Loss: 0.598622
# Train Epoch: 2 [19500]	Loss: 0.509678
# Train Epoch: 2 [20000]	Loss: 0.539730
# Train Epoch: 2 [20500]	Loss: 0.474229
# Train Epoch: 2 [21000]	Loss: 0.514453
# Train Epoch: 2 [21500]	Loss: 0.344300
# Train Epoch: 2 [22000]	Loss: 0.403135
# Train Epoch: 2 [22500]	Loss: 0.678254
# Train Epoch: 2 [23000]	Loss: 0.388464
# Train Epoch: 2 [23500]	Loss: 0.490208
# Train Epoch: 2 [24000]	Loss: 0.325059
# Train Epoch: 2 [24500]	Loss: 0.545647
# Train Epoch: 2 [25000]	Loss: 0.264716
# Train Epoch: 2 [25500]	Loss: 0.360569
# Train Epoch: 2 [26000]	Loss: 0.237293
# Train Epoch: 2 [26500]	Loss: 0.547252
# Train Epoch: 2 [27000]	Loss: 0.398611
# Train Epoch: 2 [27500]	Loss: 0.495882
# Train Epoch: 2 [28000]	Loss: 0.199130
# Train Epoch: 2 [28500]	Loss: 0.370467
# Train Epoch: 2 [29000]	Loss: 0.445701
# Train Epoch: 2 [29500]	Loss: 0.470775
# Train Epoch: 2 [30000]	Loss: 0.367054
# Train Epoch: 2 [30500]	Loss: 0.642192
# Train Epoch: 2 [31000]	Loss: 0.399700
# Train Epoch: 2 [31500]	Loss: 0.405873
# Train Epoch: 2 [32000]	Loss: 0.486070
# Train Epoch: 2 [32500]	Loss: 0.435413
# Train Epoch: 2 [33000]	Loss: 0.527724
# Train Epoch: 2 [33500]	Loss: 0.412883
# Train Epoch: 2 [34000]	Loss: 0.640514
# Train Epoch: 2 [34500]	Loss: 0.562522
# Train Epoch: 2 [35000]	Loss: 0.261015
# Train Epoch: 2 [35500]	Loss: 0.445466
# Train Epoch: 2 [36000]	Loss: 0.406088
# Train Epoch: 2 [36500]	Loss: 0.370631
# Train Epoch: 2 [37000]	Loss: 0.356754
# Train Epoch: 2 [37500]	Loss: 0.466676
# Train Epoch: 2 [38000]	Loss: 0.314704
# Train Epoch: 2 [38500]	Loss: 0.666019
# Train Epoch: 2 [39000]	Loss: 0.431613
# Train Epoch: 2 [39500]	Loss: 0.354348
# Train Epoch: 2 [40000]	Loss: 0.221194
# Train Epoch: 2 [40500]	Loss: 0.272824
# Train Epoch: 2 [41000]	Loss: 0.355761
# Train Epoch: 2 [41500]	Loss: 0.610071
# Train Epoch: 2 [42000]	Loss: 0.556562
# Train Epoch: 2 [42500]	Loss: 0.575990
# Train Epoch: 2 [43000]	Loss: 0.483745
# Train Epoch: 2 [43500]	Loss: 0.338175
# Train Epoch: 2 [44000]	Loss: 0.445587
# Train Epoch: 2 [44500]	Loss: 0.268754
# Train Epoch: 2 [45000]	Loss: 0.845813
# Train Epoch: 2 [45500]	Loss: 0.563307
# Train Epoch: 2 [46000]	Loss: 0.442070
# Train Epoch: 2 [46500]	Loss: 0.348187
# Train Epoch: 2 [47000]	Loss: 0.440873
# Train Epoch: 2 [47500]	Loss: 0.502252
# Train Epoch: 2 [48000]	Loss: 0.536240
# Train Epoch: 2 [48500]	Loss: 0.429044
# Train Epoch: 2 [49000]	Loss: 0.591101
# Train Epoch: 2 [49500]	Loss: 0.869636
# Train Epoch: 2 [50000]	Loss: 0.342950
# Train Epoch: 2 [50500]	Loss: 0.445642
# Train Epoch: 2 [51000]	Loss: 0.321721
# Train Epoch: 2 [51500]	Loss: 0.358243
# Train Epoch: 2 [52000]	Loss: 0.491012
# Train Epoch: 2 [52500]	Loss: 0.278737
# Train Epoch: 2 [53000]	Loss: 0.349584
# Train Epoch: 2 [53500]	Loss: 0.467669
# Train Epoch: 2 [54000]	Loss: 0.432315
# Train Epoch: 2 [54500]	Loss: 0.386603
# Train Epoch: 2 [55000]	Loss: 0.341895
# Train Epoch: 2 [55500]	Loss: 0.318325
# Train Epoch: 2 [56000]	Loss: 0.382987
# Train Epoch: 2 [56500]	Loss: 0.246570
# Train Epoch: 2 [57000]	Loss: 0.540238
# Train Epoch: 2 [57500]	Loss: 0.430636
# Train Epoch: 2 [58000]	Loss: 0.331231
# Train Epoch: 2 [58500]	Loss: 0.297051
# Train Epoch: 2 [59000]	Loss: 0.235408
# Train Epoch: 2 [59500]	Loss: 0.199273
# Train Epoch: 3 [0]	Loss: 0.400044
# Train Epoch: 3 [500]	Loss: 0.550154
# Train Epoch: 3 [1000]	Loss: 0.455865
# Train Epoch: 3 [1500]	Loss: 0.305580
# Train Epoch: 3 [2000]	Loss: 0.219671
# Train Epoch: 3 [2500]	Loss: 0.216790
# Train Epoch: 3 [3000]	Loss: 0.772111
# Train Epoch: 3 [3500]	Loss: 0.424467
# Train Epoch: 3 [4000]	Loss: 0.221562
# Train Epoch: 3 [4500]	Loss: 0.314093
# Train Epoch: 3 [5000]	Loss: 0.596778
# Train Epoch: 3 [5500]	Loss: 0.411864
# Train Epoch: 3 [6000]	Loss: 0.204741
# Train Epoch: 3 [6500]	Loss: 0.311818
# Train Epoch: 3 [7000]	Loss: 0.673500
# Train Epoch: 3 [7500]	Loss: 0.438785
# Train Epoch: 3 [8000]	Loss: 0.223492
# Train Epoch: 3 [8500]	Loss: 0.251411
# Train Epoch: 3 [9000]	Loss: 0.189999
# Train Epoch: 3 [9500]	Loss: 0.529615
# Train Epoch: 3 [10000]	Loss: 0.608202
# Train Epoch: 3 [10500]	Loss: 0.278349
# Train Epoch: 3 [11000]	Loss: 0.489920
# Train Epoch: 3 [11500]	Loss: 0.301820
# Train Epoch: 3 [12000]	Loss: 0.321428
# Train Epoch: 3 [12500]	Loss: 0.441694
# Train Epoch: 3 [13000]	Loss: 0.578895
# Train Epoch: 3 [13500]	Loss: 0.436890
# Train Epoch: 3 [14000]	Loss: 0.448005
# Train Epoch: 3 [14500]	Loss: 0.508362
# Train Epoch: 3 [15000]	Loss: 0.219703
# Train Epoch: 3 [15500]	Loss: 0.398595
# Train Epoch: 3 [16000]	Loss: 0.863632
# Train Epoch: 3 [16500]	Loss: 0.205750
# Train Epoch: 3 [17000]	Loss: 0.238290
# Train Epoch: 3 [17500]	Loss: 0.579343
# Train Epoch: 3 [18000]	Loss: 0.498703
# Train Epoch: 3 [18500]	Loss: 0.214678
# Train Epoch: 3 [19000]	Loss: 0.328303
# Train Epoch: 3 [19500]	Loss: 0.400631
# Train Epoch: 3 [20000]	Loss: 0.488153
# Train Epoch: 3 [20500]	Loss: 0.257813
# Train Epoch: 3 [21000]	Loss: 0.428887
# Train Epoch: 3 [21500]	Loss: 0.277268
# Train Epoch: 3 [22000]	Loss: 0.288379
# Train Epoch: 3 [22500]	Loss: 0.729495
# Train Epoch: 3 [23000]	Loss: 0.324483
# Train Epoch: 3 [23500]	Loss: 0.194458
# Train Epoch: 3 [24000]	Loss: 0.449134
# Train Epoch: 3 [24500]	Loss: 0.428517
# Train Epoch: 3 [25000]	Loss: 0.244504
# Train Epoch: 3 [25500]	Loss: 0.249543
# Train Epoch: 3 [26000]	Loss: 0.262745
# Train Epoch: 3 [26500]	Loss: 0.360282
# Train Epoch: 3 [27000]	Loss: 0.326028
# Train Epoch: 3 [27500]	Loss: 0.484073
# Train Epoch: 3 [28000]	Loss: 0.193210
# Train Epoch: 3 [28500]	Loss: 0.290454
# Train Epoch: 3 [29000]	Loss: 0.274929
# Train Epoch: 3 [29500]	Loss: 0.294618
# Train Epoch: 3 [30000]	Loss: 0.471348
# Train Epoch: 3 [30500]	Loss: 0.537493
# Train Epoch: 3 [31000]	Loss: 0.416055
# Train Epoch: 3 [31500]	Loss: 0.317295
# Train Epoch: 3 [32000]	Loss: 0.506906
# Train Epoch: 3 [32500]	Loss: 0.431944
# Train Epoch: 3 [33000]	Loss: 0.223455
# Train Epoch: 3 [33500]	Loss: 0.325695
# Train Epoch: 3 [34000]	Loss: 0.411262
# Train Epoch: 3 [34500]	Loss: 0.437952
# Train Epoch: 3 [35000]	Loss: 0.221211
# Train Epoch: 3 [35500]	Loss: 0.365829
# Train Epoch: 3 [36000]	Loss: 0.239515
# Train Epoch: 3 [36500]	Loss: 0.298489
# Train Epoch: 3 [37000]	Loss: 0.306797
# Train Epoch: 3 [37500]	Loss: 0.560201
# Train Epoch: 3 [38000]	Loss: 0.250374
# Train Epoch: 3 [38500]	Loss: 0.607034
# Train Epoch: 3 [39000]	Loss: 0.366069
# Train Epoch: 3 [39500]	Loss: 0.257799
# Train Epoch: 3 [40000]	Loss: 0.382994
# Train Epoch: 3 [40500]	Loss: 0.204980
# Train Epoch: 3 [41000]	Loss: 0.366128
# Train Epoch: 3 [41500]	Loss: 0.412990
# Train Epoch: 3 [42000]	Loss: 0.258408
# Train Epoch: 3 [42500]	Loss: 0.537436
# Train Epoch: 3 [43000]	Loss: 0.434418
# Train Epoch: 3 [43500]	Loss: 0.246384
# Train Epoch: 3 [44000]	Loss: 0.245444
# Train Epoch: 3 [44500]	Loss: 0.145840
# Train Epoch: 3 [45000]	Loss: 0.365184
# Train Epoch: 3 [45500]	Loss: 0.653915
# Train Epoch: 3 [46000]	Loss: 0.498044
# Train Epoch: 3 [46500]	Loss: 0.174244
# Train Epoch: 3 [47000]	Loss: 0.396293
# Train Epoch: 3 [47500]	Loss: 0.304124
# Train Epoch: 3 [48000]	Loss: 0.326726
# Train Epoch: 3 [48500]	Loss: 0.272416
# Train Epoch: 3 [49000]	Loss: 0.695149
# Train Epoch: 3 [49500]	Loss: 0.775996
# Train Epoch: 3 [50000]	Loss: 0.309709
# Train Epoch: 3 [50500]	Loss: 0.278198
# Train Epoch: 3 [51000]	Loss: 0.202097
# Train Epoch: 3 [51500]	Loss: 0.294279
# Train Epoch: 3 [52000]	Loss: 0.246268
# Train Epoch: 3 [52500]	Loss: 0.190802
# Train Epoch: 3 [53000]	Loss: 0.422827
# Train Epoch: 3 [53500]	Loss: 0.393254
# Train Epoch: 3 [54000]	Loss: 0.502386
# Train Epoch: 3 [54500]	Loss: 0.170780
# Train Epoch: 3 [55000]	Loss: 0.305896
# Train Epoch: 3 [55500]	Loss: 0.321470
# Train Epoch: 3 [56000]	Loss: 0.316671
# Train Epoch: 3 [56500]	Loss: 0.222545
# Train Epoch: 3 [57000]	Loss: 0.295373
# Train Epoch: 3 [57500]	Loss: 0.598295
# Train Epoch: 3 [58000]	Loss: 0.202703
# Train Epoch: 3 [58500]	Loss: 0.132980
# Train Epoch: 3 [59000]	Loss: 0.083501
# Train Epoch: 3 [59500]	Loss: 0.179375
# Train Epoch: 4 [0]	Loss: 0.408798
# Train Epoch: 4 [500]	Loss: 0.322313
# Train Epoch: 4 [1000]	Loss: 0.182953
# Train Epoch: 4 [1500]	Loss: 0.477370
# Train Epoch: 4 [2000]	Loss: 0.712613
# Train Epoch: 4 [2500]	Loss: 0.369146
# Train Epoch: 4 [3000]	Loss: 0.223975
# Train Epoch: 4 [3500]	Loss: 0.355748
# Train Epoch: 4 [4000]	Loss: 0.236034
# Train Epoch: 4 [4500]	Loss: 0.240393
# Train Epoch: 4 [5000]	Loss: 0.341245
# Train Epoch: 4 [5500]	Loss: 0.498039
# Train Epoch: 4 [6000]	Loss: 0.181577
# Train Epoch: 4 [6500]	Loss: 0.190049
# Train Epoch: 4 [7000]	Loss: 0.558551
# Train Epoch: 4 [7500]	Loss: 0.293270
# Train Epoch: 4 [8000]	Loss: 0.420384
# Train Epoch: 4 [8500]	Loss: 0.223212
# Train Epoch: 4 [9000]	Loss: 0.415300
# Train Epoch: 4 [9500]	Loss: 0.193731
# Train Epoch: 4 [10000]	Loss: 0.182758
# Train Epoch: 4 [10500]	Loss: 0.223056
# Train Epoch: 4 [11000]	Loss: 0.213119
# Train Epoch: 4 [11500]	Loss: 0.310327
# Train Epoch: 4 [12000]	Loss: 0.248454
# Train Epoch: 4 [12500]	Loss: 0.369379
# Train Epoch: 4 [13000]	Loss: 0.274159
# Train Epoch: 4 [13500]	Loss: 0.238770
# Train Epoch: 4 [14000]	Loss: 0.250833
# Train Epoch: 4 [14500]	Loss: 0.324519
# Train Epoch: 4 [15000]	Loss: 0.238664
# Train Epoch: 4 [15500]	Loss: 0.254160
# Train Epoch: 4 [16000]	Loss: 0.155910
# Train Epoch: 4 [16500]	Loss: 0.179129
# Train Epoch: 4 [17000]	Loss: 0.403496
# Train Epoch: 4 [17500]	Loss: 0.436394
# Train Epoch: 4 [18000]	Loss: 0.162069
# Train Epoch: 4 [18500]	Loss: 0.219302
# Train Epoch: 4 [19000]	Loss: 0.141286
# Train Epoch: 4 [19500]	Loss: 0.650721
# Train Epoch: 4 [20000]	Loss: 0.216414
# Train Epoch: 4 [20500]	Loss: 0.770127
# Train Epoch: 4 [21000]	Loss: 0.618132
# Train Epoch: 4 [21500]	Loss: 0.321832
# Train Epoch: 4 [22000]	Loss: 0.398026
# Train Epoch: 4 [22500]	Loss: 0.307972
# Train Epoch: 4 [23000]	Loss: 0.592033
# Train Epoch: 4 [23500]	Loss: 0.293540
# Train Epoch: 4 [24000]	Loss: 0.475783
# Train Epoch: 4 [24500]	Loss: 0.110645
# Train Epoch: 4 [25000]	Loss: 0.292381
# Train Epoch: 4 [25500]	Loss: 0.092609
# Train Epoch: 4 [26000]	Loss: 0.325907
# Train Epoch: 4 [26500]	Loss: 0.303152
# Train Epoch: 4 [27000]	Loss: 0.149402
# Train Epoch: 4 [27500]	Loss: 0.253924
# Train Epoch: 4 [28000]	Loss: 0.570436
# Train Epoch: 4 [28500]	Loss: 0.104703
# Train Epoch: 4 [29000]	Loss: 0.111124
# Train Epoch: 4 [29500]	Loss: 0.112357
# Train Epoch: 4 [30000]	Loss: 0.886934
# Train Epoch: 4 [30500]	Loss: 0.322271
# Train Epoch: 4 [31000]	Loss: 0.271807
# Train Epoch: 4 [31500]	Loss: 0.313173
# Train Epoch: 4 [32000]	Loss: 0.132159
# Train Epoch: 4 [32500]	Loss: 0.299293
# Train Epoch: 4 [33000]	Loss: 0.422546
# Train Epoch: 4 [33500]	Loss: 0.250853
# Train Epoch: 4 [34000]	Loss: 0.304613
# Train Epoch: 4 [34500]	Loss: 0.277991
# Train Epoch: 4 [35000]	Loss: 0.165748
# Train Epoch: 4 [35500]	Loss: 0.122985
# Train Epoch: 4 [36000]	Loss: 0.329647
# Train Epoch: 4 [36500]	Loss: 0.144329
# Train Epoch: 4 [37000]	Loss: 0.274125
# Train Epoch: 4 [37500]	Loss: 0.493320
# Train Epoch: 4 [38000]	Loss: 0.344183
# Train Epoch: 4 [38500]	Loss: 0.512585
# Train Epoch: 4 [39000]	Loss: 0.823278
# Train Epoch: 4 [39500]	Loss: 0.373981
# Train Epoch: 4 [40000]	Loss: 0.205794
# Train Epoch: 4 [40500]	Loss: 0.791143
# Train Epoch: 4 [41000]	Loss: 0.435358
# Train Epoch: 4 [41500]	Loss: 0.319814
# Train Epoch: 4 [42000]	Loss: 0.508916
# Train Epoch: 4 [42500]	Loss: 0.244445
# Train Epoch: 4 [43000]	Loss: 0.246359
# Train Epoch: 4 [43500]	Loss: 0.158205
# Train Epoch: 4 [44000]	Loss: 0.408023
# Train Epoch: 4 [44500]	Loss: 0.202372
# Train Epoch: 4 [45000]	Loss: 0.561822
# Train Epoch: 4 [45500]	Loss: 0.162702
# Train Epoch: 4 [46000]	Loss: 0.464171
# Train Epoch: 4 [46500]	Loss: 0.474056
# Train Epoch: 4 [47000]	Loss: 0.197247
# Train Epoch: 4 [47500]	Loss: 0.474386
# Train Epoch: 4 [48000]	Loss: 0.425166
# Train Epoch: 4 [48500]	Loss: 0.314874
# Train Epoch: 4 [49000]	Loss: 0.662395
# Train Epoch: 4 [49500]	Loss: 0.324788
# Train Epoch: 4 [50000]	Loss: 0.094839
# Train Epoch: 4 [50500]	Loss: 0.237410
# Train Epoch: 4 [51000]	Loss: 0.440275
# Train Epoch: 4 [51500]	Loss: 0.119467
# Train Epoch: 4 [52000]	Loss: 0.151921
# Train Epoch: 4 [52500]	Loss: 0.249655
# Train Epoch: 4 [53000]	Loss: 0.271498
# Train Epoch: 4 [53500]	Loss: 0.129102
# Train Epoch: 4 [54000]	Loss: 0.335741
# Train Epoch: 4 [54500]	Loss: 0.142123
# Train Epoch: 4 [55000]	Loss: 0.234784
# Train Epoch: 4 [55500]	Loss: 0.226330
# Train Epoch: 4 [56000]	Loss: 0.248170
# Train Epoch: 4 [56500]	Loss: 0.141262
# Train Epoch: 4 [57000]	Loss: 0.437655
# Train Epoch: 4 [57500]	Loss: 0.377884
# Train Epoch: 4 [58000]	Loss: 0.421444
# Train Epoch: 4 [58500]	Loss: 0.223979
# Train Epoch: 4 [59000]	Loss: 0.393424
# Train Epoch: 4 [59500]	Loss: 0.278155
# Train Epoch: 5 [0]	Loss: 0.248663
# Train Epoch: 5 [500]	Loss: 0.439836
# Train Epoch: 5 [1000]	Loss: 0.329774
# Train Epoch: 5 [1500]	Loss: 0.349114
# Train Epoch: 5 [2000]	Loss: 0.197181
# Train Epoch: 5 [2500]	Loss: 0.171074
# Train Epoch: 5 [3000]	Loss: 0.388011
# Train Epoch: 5 [3500]	Loss: 0.441931
# Train Epoch: 5 [4000]	Loss: 0.194830
# Train Epoch: 5 [4500]	Loss: 0.218896
# Train Epoch: 5 [5000]	Loss: 0.308434
# Train Epoch: 5 [5500]	Loss: 0.348354
# Train Epoch: 5 [6000]	Loss: 0.226972
# Train Epoch: 5 [6500]	Loss: 0.152828
# Train Epoch: 5 [7000]	Loss: 0.559645
# Train Epoch: 5 [7500]	Loss: 0.371759
# Train Epoch: 5 [8000]	Loss: 0.178409
# Train Epoch: 5 [8500]	Loss: 0.279845
# Train Epoch: 5 [9000]	Loss: 0.148481
# Train Epoch: 5 [9500]	Loss: 0.228570
# Train Epoch: 5 [10000]	Loss: 0.349643
# Train Epoch: 5 [10500]	Loss: 0.143925
# Train Epoch: 5 [11000]	Loss: 0.374336
# Train Epoch: 5 [11500]	Loss: 0.217828
# Train Epoch: 5 [12000]	Loss: 0.170661
# Train Epoch: 5 [12500]	Loss: 0.427475
# Train Epoch: 5 [13000]	Loss: 0.530384
# Train Epoch: 5 [13500]	Loss: 0.282544
# Train Epoch: 5 [14000]	Loss: 0.202075
# Train Epoch: 5 [14500]	Loss: 0.379237
# Train Epoch: 5 [15000]	Loss: 0.142453
# Train Epoch: 5 [15500]	Loss: 0.349026
# Train Epoch: 5 [16000]	Loss: 0.535488
# Train Epoch: 5 [16500]	Loss: 0.129793
# Train Epoch: 5 [17000]	Loss: 0.334431
# Train Epoch: 5 [17500]	Loss: 0.435702
# Train Epoch: 5 [18000]	Loss: 0.423636
# Train Epoch: 5 [18500]	Loss: 0.222963
# Train Epoch: 5 [19000]	Loss: 0.231058
# Train Epoch: 5 [19500]	Loss: 0.285586
# Train Epoch: 5 [20000]	Loss: 0.419423
# Train Epoch: 5 [20500]	Loss: 0.163467
# Train Epoch: 5 [21000]	Loss: 0.317448
# Train Epoch: 5 [21500]	Loss: 0.113456
# Train Epoch: 5 [22000]	Loss: 0.209970
# Train Epoch: 5 [22500]	Loss: 0.411300
# Train Epoch: 5 [23000]	Loss: 0.358767
# Train Epoch: 5 [23500]	Loss: 0.106098
# Train Epoch: 5 [24000]	Loss: 0.221447
# Train Epoch: 5 [24500]	Loss: 0.294949
# Train Epoch: 5 [25000]	Loss: 0.159623
# Train Epoch: 5 [25500]	Loss: 0.280754
# Train Epoch: 5 [26000]	Loss: 0.325138
# Train Epoch: 5 [26500]	Loss: 0.383934
# Train Epoch: 5 [27000]	Loss: 0.156484
# Train Epoch: 5 [27500]	Loss: 0.422869
# Train Epoch: 5 [28000]	Loss: 0.252484
# Train Epoch: 5 [28500]	Loss: 0.329481
# Train Epoch: 5 [29000]	Loss: 0.258576
# Train Epoch: 5 [29500]	Loss: 0.204541
# Train Epoch: 5 [30000]	Loss: 0.433402
# Train Epoch: 5 [30500]	Loss: 0.309093
# Train Epoch: 5 [31000]	Loss: 0.145184
# Train Epoch: 5 [31500]	Loss: 0.131809
# Train Epoch: 5 [32000]	Loss: 0.403447
# Train Epoch: 5 [32500]	Loss: 0.194660
# Train Epoch: 5 [33000]	Loss: 0.190102
# Train Epoch: 5 [33500]	Loss: 0.193358
# Train Epoch: 5 [34000]	Loss: 0.383831
# Train Epoch: 5 [34500]	Loss: 0.423647
# Train Epoch: 5 [35000]	Loss: 0.275508
# Train Epoch: 5 [35500]	Loss: 0.227481
# Train Epoch: 5 [36000]	Loss: 0.265214
# Train Epoch: 5 [36500]	Loss: 0.200319
# Train Epoch: 5 [37000]	Loss: 0.205366
# Train Epoch: 5 [37500]	Loss: 0.378878
# Train Epoch: 5 [38000]	Loss: 0.196709
# Train Epoch: 5 [38500]	Loss: 0.399730
# Train Epoch: 5 [39000]	Loss: 0.183161
# Train Epoch: 5 [39500]	Loss: 0.302746
# Train Epoch: 5 [40000]	Loss: 0.276422
# Train Epoch: 5 [40500]	Loss: 0.252155
# Train Epoch: 5 [41000]	Loss: 0.272182
# Train Epoch: 5 [41500]	Loss: 0.215781
# Train Epoch: 5 [42000]	Loss: 0.229265
# Train Epoch: 5 [42500]	Loss: 0.489462
# Train Epoch: 5 [43000]	Loss: 0.430375
# Train Epoch: 5 [43500]	Loss: 0.310469
# Train Epoch: 5 [44000]	Loss: 0.195736
# Train Epoch: 5 [44500]	Loss: 0.285110
# Train Epoch: 5 [45000]	Loss: 0.445110
# Train Epoch: 5 [45500]	Loss: 0.255691
# Train Epoch: 5 [46000]	Loss: 0.438038
# Train Epoch: 5 [46500]	Loss: 0.117561
# Train Epoch: 5 [47000]	Loss: 0.328647
# Train Epoch: 5 [47500]	Loss: 0.277284
# Train Epoch: 5 [48000]	Loss: 0.137376
# Train Epoch: 5 [48500]	Loss: 0.187580
# Train Epoch: 5 [49000]	Loss: 0.425723
# Train Epoch: 5 [49500]	Loss: 0.894008
# Train Epoch: 5 [50000]	Loss: 0.161128
# Train Epoch: 5 [50500]	Loss: 0.285601
# Train Epoch: 5 [51000]	Loss: 0.098057
# Train Epoch: 5 [51500]	Loss: 0.253818
# Train Epoch: 5 [52000]	Loss: 0.231236
# Train Epoch: 5 [52500]	Loss: 0.165722
# Train Epoch: 5 [53000]	Loss: 0.256798
# Train Epoch: 5 [53500]	Loss: 0.212539
# Train Epoch: 5 [54000]	Loss: 0.289612
# Train Epoch: 5 [54500]	Loss: 0.231171
# Train Epoch: 5 [55000]	Loss: 0.218573
# Train Epoch: 5 [55500]	Loss: 0.351632
# Train Epoch: 5 [56000]	Loss: 0.206175
# Train Epoch: 5 [56500]	Loss: 0.101267
# Train Epoch: 5 [57000]	Loss: 0.266900
# Train Epoch: 5 [57500]	Loss: 0.304647
# Train Epoch: 5 [58000]	Loss: 0.186643
# Train Epoch: 5 [58500]	Loss: 0.066923
# Train Epoch: 5 [59000]	Loss: 0.118703
# Train Epoch: 5 [59500]	Loss: 0.069370

# %% [markdown]
# ## Step 6: Plot Training Results
#
# Inside the `train_fn` function we saved the training history to HDFS, which means we can later read it in %%local mode for plotting.

# %%
# %%local
# import json
# from hops import hdfs
# import matplotlib.pyplot as plt
# from pylab import rcParams
# results_path = hdfs.project_path() + "mnist/mnist_train_results_2.txt"
# results = json.loads(hdfs.load(results_path))

# %% [markdown]
# ### Plot Loss/Epoch During Training

# %%
# %%local
# %matplotlib inline
# y = results["loss"] #loss
# x = list(range(1, len(y)+1))#epoch
# plt.title("Loss per Epoch - MNIST Training")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.plot(x,y)

# %% [markdown]
# ### Plot Accuracy/Epoch During Training

# %%
# %%local
# %matplotlib inline
# y = results["acc"] #acc
# x = list(range(1, len(y)+1))#epoch
# plt.title("Accuracy per Epoch - MNIST Training")
# plt.xlabel("Epoch")
# plt.ylabel("Accuracy")
# plt.plot(x,y)

# %% [markdown]
# ## Step 7: Evaluation Using Trained Model and Test Dataset
#
# Inside the train_fn function we saved the trained model to HDFS in the ps format. We can load the weights of this model and use for serving predictions or for evaluation, in this example we will evaluate the model against the test set.

# %% [markdown]
# ### Load Model Weights

# %%
model_path_hdfs = hdfs.project_path() + "mnist/" + "mnist_torch_ps.pt"

# %% [markdown]
# Currently PyTorch HDFS support is limited. To get around this we can localize the ps model in the local file system and load it from there using `torch.load`.

# %%
local_path = hdfs.localize(model_path_hdfs)

# %%
model = Net()
model.load_state_dict(torch.load(local_path))

# %%
def test_epoch(test_dataset_path, model, device, epoch):
    """
    Function for testing a single epoch of MNIST test dataset using PyTorch
    """
    with DataLoader(make_reader(test_dataset_path, num_epochs=READER_EPOCHS, hdfs_driver='libhdfs'), 
                    batch_size=BATCH_SIZE, transform=_transform_row) as test_loader:
        model.eval()
        test_loss = 0
        correct = 0
        count = 0
        with torch.no_grad():
            for row in test_loader:
                data, target = row['image'].to(device), row['digit'].to(device)
                output = model(data)
                test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
                pred = output.max(1, keepdim=True)[1]  # get the index of the max log-probability
                correct += pred.eq(target.view_as(pred)).sum().item()
                count += data.shape[0]

        test_loss /= count
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, count, 100. * correct / count))

# %%
def test_fn(model):
    # Setup Torch
    use_cuda = torch.cuda.is_available()
    torch.manual_seed(SEED)
    device = torch.device('cuda' if use_cuda else 'cpu')
    # get dataset path from the featurestore
    test_dataset_path = featurestore.get_training_dataset_path(TEST_DATASET_NAME)
    for epoch in range(1, NUM_EPOCHS + 1):
        test_epoch(test_dataset_path, model, device, epoch)

# %%
test_fn(model)
# Out:
# Test set: Average loss: 0.2770, Accuracy: 9159/10000 (92%)
